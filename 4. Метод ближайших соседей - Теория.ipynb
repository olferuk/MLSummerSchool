# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

pd.options.display.max_columns = 200

# %%
def plot_decision_boundary(clf, X, Y, h=0.1):
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))
    
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    
    plt.figure(figsize=(8,8));
    plt.contourf(xx,     yy,        Z, alpha=0.8); # cmap=plt.cm.Blues,
    plt.scatter(X[:, 0], X[:, 1], c=Y,); #  cmap=plt.cm.autumn
    plt.title('Decision boundary');

# %%
from sklearn.datasets import make_classification, make_blobs

# %%
CLUSTERS = 21
EXAMPLES_EACH = 1

# %%
X1, Y1 = make_blobs(n_features=2, centers=CLUSTERS, n_samples=EXAMPLES_EACH*CLUSTERS)
plt.figure(figsize=(8,8));
plt.scatter(X1[:, 0], X1[:, 1], marker='o', c=Y1); #, cmap=plt.cm.Accent

# %%
from sklearn.neighbors import KNeighborsClassifier

lr = KNeighborsClassifier(n_neighbors=1)
lr.fit(X1, Y1);

plot_decision_boundary(lr, X1, Y1);

# %%
xx, yy = np.meshgrid(np.linspace(-3, 3, 50),
                     np.linspace(-3, 3, 50))
X = np.random.randn(200, 2)
Y = np.logical_xor(X[:, 0] > 0, X[:, 1] > 0).astype(np.int64)

# %%
plt.figure(figsize=(8,8));
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap=plt.cm.Accent);

# %%
lr = KNeighborsClassifier(n_neighbors=1)
lr.fit(X, Y);

plot_decision_boundary(lr, X, Y);

# %%
lr = KNeighborsClassifier(n_neighbors=8)
lr.fit(X, Y);

plot_decision_boundary(lr, X, Y);

# %%
lr = KNeighborsClassifier(n_neighbors=70)
lr.fit(X, Y);

plot_decision_boundary(lr, X, Y);
